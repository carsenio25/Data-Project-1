# %%
import os
import numpy
import pandas as pd
from sqlalchemy import create_engine

# %%
host_name = "localhost"
port = "3306"
user_id = "root"
pwd = "Passw0rd123"

src_dbname = "chinook"
dst_dbname = "music_data"

src_engine = create_engine(f'mysql+mysqlconnector://{user_id}:{pwd}@{host_name}/{src_dbname}')
engine = create_engine(f'mysql+mysqlconnector://{user_id}:{pwd}@{host_name}/{dst_dbname}')

# %%
def get_dataframe(user_id, pwd, host_name, db_name, sql_query):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    dframe = pd.read_sql(sql_query, connection);
    connection.close()
    
    return dframe


def set_dataframe(user_id, pwd, host_name, db_name, df, table_name, pk_column, db_operation):
    conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}/{db_name}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        connection.execute(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});")
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()

# %%
conn_str = f"mysql+pymysql://{user_id}:{pwd}@{host_name}"
sqlEngine = create_engine(conn_str, pool_recycle=3600)
connection = sqlEngine.connect()

# The ETL Pipeline starts in the file fetching from the spotify api, and it already puts a tentative dim_tracks in music_data
# so we can't drop it and create it again here. Therefore these lines are commented out
#connection.execute(f"DROP DATABASE IF EXISTS `{dst_dbname}`;")
#connection.execute(f"CREATE DATABASE `{dst_dbname}`;")
connection.execute(f"USE {dst_dbname};")

connection.close()

# %%
# Load the song popularity data from csv file into a pandas df
song_pop_df = pd.read_csv('song_pop.csv', sep='\t')

song_pop_df.head(2)
# Out:
#                   song_id  year_end_score  is_pop  year
# 0  0tgVpDi06FyKpA1z0VMD4v            5617    True  2018
# 1  3lFf4DnT68QjQGB3iq1BJ9            5549    True  2018

# %%
# Renaming columns to fit with conventions of rest of tables
song_pop_df.rename(columns={'year': 'MeasuredPopularityYear', 'is_pop': 'IsPopular', 'year_end_score': 'PopularityScore'}, inplace=True)
song_pop_df.head(2)
# Out:
#                   song_id  PopularityScore  IsPopular  MeasuredPopularityYear
# 0  0tgVpDi06FyKpA1z0VMD4v             5617       True                    2018
# 1  3lFf4DnT68QjQGB3iq1BJ9             5549       True                    2018

# %%
# Import dim_tracks from dst database as a df
dim_tracks_df = pd.read_sql_table('dim_tracks', con=engine)
# Merge this with the song popularity dataframe
merged_df = pd.merge(dim_tracks_df, song_pop_df, left_on='spotify_track_id', right_on='song_id', how='left')

# %%
merged_df.head(100)
# Out:
#           spotify_track_id                                song_name  \
# 0   17lu4tymfnhmcIDlzBbtAb  For Those About To Rock (We Salute You)
# 1   2dbOYFfS7r7NAzquRvji9A                        Balls to the Wall
# 2   204523f9MSgEfc0oDJycNS                          Fast As a Shark
# 3   5O0FdpixX4OhV75VVUEt2p                        Restless and Wild
# 27             5       265773  3XYqOJI1YlX40kJTdzFEzp
# 28             5       265773  3XYqOJI1YlX40kJTdzFEzp
# 29            11       328560  33lrptYaoQiDsAcZPXKFna
# 30             9       308560  180jTzor4W2MQ9HW5h5Fh4
# 31             4       238333  3WFTGIO6E3Xh4paEOBY9OU
# 32             4       238333  3WFTGIO6E3Xh4paEOBY9OU
# 33             1       428133  1qVP93dewrI7bukJAFPIvV
# 34            10       215866  2uT123xlHuqvz14JR0KQSs
# 35             1       164227  5hJtcqGwi9lmFElCqPRnlS
# 36             6       204815  3zu0hJJew2qXZNlselIQk8
# 37             2       250600  180jTzor4W2MQ9HW5h5Fh4
# 38             9       188666  507VZINfvVEAyrcPbJuOVU
# 39            15       381400  2uT123xlHuqvz14JR0KQSs
# 40             4       191800  5TkaDC4mYSLBvdG6UrIB0v
# 41             2       249493  5Ap3F8CxjjsQKZGASDcHNA
# 42             5       263400  3T4tUhGYeRNVUGevb0wThu
# 43             5       263400  3T4tUhGYeRNVUGevb0wThu
# 44             4       222013  5Ap3F8CxjjsQKZGASDcHNA
# 45             5       176133  5Ap3F8CxjjsQKZGASDcHNA
# 46            13       368739  30zwjSQEodaUXCn11nmiVF
# 47             3       251626  4HPdvrPf9RGfJ2hNYrODpC
# 48             3       251626  4HPdvrPf9RGfJ2hNYrODpC
# 49             8       267293  5Ap3F8CxjjsQKZGASDcHNA
# 50            17       273600  3q6Bz38jmqRDkXI7j5Hb9Y
# 51            17       273600  3q6Bz38jmqRDkXI7j5Hb9Y
# 52            10       230000  5Ap3F8CxjjsQKZGASDcHNA
# 53            11       226266  5Ap3F8CxjjsQKZGASDcHNA
# 54             1       247426  2H6i2CrWgXE1HookLu8Au0
# 55            13       248733  1q9Bs3reVhgnAsihJecVav
#
#                                            album_name  track_count  \
# 0             For Those About to Rock (We Salute You)           10
# 1                                   Balls To The Wall           12
# 2                                   Restless And Wild           10
# 3                                   Restless And Wild           10
# 4                                   Restless And Wild           10
# 5                                      Feel the Music           12
# 6                         Disney Channel Play It Loud           14
# 7             For Those About to Rock (We Salute You)           10
# 8             For Those About to Rock (We Salute You)           10
# 9             For Those About to Rock (We Salute You)           10
# 10                                    Radical $uicide            5
# 11                                  High Expectations           20
# 12            For Those About to Rock (We Salute You)           10
# 13                                     The Best Of...           15
# 14                                                A/B           10
# 15                                        Dog Eat Dog            1
# 16                                  Let There Be Rock            8
# 17                                Girls, Girls, Girls           15
# 18                                    Problem Child 3           14
# 19                                I’d Rather Overdose            1
# 20                                  Let There Be Rock            8
# 21                                  Let There Be Rock            8
# 22                                            AMERICA           12
# 23                                           Big Ones           15
# 24                                 Permanent Vacation           12
# 25                                             Evolve           12
# 26                                             Evolve           12
# 27                                 Permanent Vacation           12
# 28                                 Permanent Vacation           12
# 29                    Tough Love: Best Of The Ballads           12
# 30                                         Get A Grip           14
# 31                                  808s & Heartbreak           12
# 32                                  808s & Heartbreak           12
# 33                                The Roaring Silence            9
# 34                                           Big Ones           15
# 35                                     The Other Side            1
# 36                          Pa las Baby's Y Belikeada           30
# 37                                         Get A Grip           14
# 38                                       Nata Montana           15
# 39                                           Big Ones           15
# 40                                             CINEMA           13
# 41                 Jagged Little Pill (2015 Remaster)           13
# 42                                         ÷ (Deluxe)           16
# 43                                         ÷ (Deluxe)           16
# 44                 Jagged Little Pill (2015 Remaster)           13
# 45                 Jagged Little Pill (2015 Remaster)           13
# 46                                         VULTURES 1           16
# 47                            R.E.D. (Deluxe Edition)           17
# 48                            R.E.D. (Deluxe Edition)           17
# 49                 Jagged Little Pill (2015 Remaster)           13
# 50                                      Greatest Hits           18
# 51                                      Greatest Hits           18
# 52                 Jagged Little Pill (2015 Remaster)           13
# 53                 Jagged Little Pill (2015 Remaster)           13
# 54                                               True           10
# 55  Strung Out On Jagged Little Pill: VSQ Performs...           13
#
#                    song_id  PopularityScore IsPopular  MeasuredPopularityYear
# 0                      NaN              NaN       NaN                     NaN
# 1                      NaN              NaN       NaN                     NaN
# 2                      NaN              NaN       NaN                     NaN
# 3                      NaN              NaN       NaN                     NaN
# 4                      NaN              NaN       NaN                     NaN
# 5                      NaN              NaN       NaN                     NaN
# 6                      NaN              NaN       NaN                     NaN
# 7                      NaN              NaN       NaN                     NaN
# 8                      NaN              NaN       NaN                     NaN
# 9                      NaN              NaN       NaN                     NaN
# 10                     NaN              NaN       NaN                     NaN
# 11                     NaN              NaN       NaN                     NaN
# 12                     NaN              NaN       NaN                     NaN
# 13                     NaN              NaN       NaN                     NaN
# 14  0y1QJc3SJVPKJ1OvFmFqe6            274.0     False                  2017.0
# 15                     NaN              NaN       NaN                     NaN
# 16                     NaN              NaN       NaN                     NaN
# 17                     NaN              NaN       NaN                     NaN
# 18                     NaN              NaN       NaN                     NaN
# 19                     NaN              NaN       NaN                     NaN
# 20                     NaN              NaN       NaN                     NaN
# 21                     NaN              NaN       NaN                     NaN
# 22                     NaN              NaN       NaN                     NaN
# 23                     NaN              NaN       NaN                     NaN
# 24  2KCJYwlBWxdlwyIYckIf6V           1294.0      True                  1988.0
# 25  6Qn5zhYkTa37e91HC1D7lb           2372.0      True                  2018.0
# 26  6Qn5zhYkTa37e91HC1D7lb              9.0     False                  2017.0
# 27  6gQUbFwwdYXlKdmqRoWKJe            728.0     False                  1988.0
# 28  6gQUbFwwdYXlKdmqRoWKJe            895.0      True                  1987.0
# 29                     NaN              NaN       NaN                     NaN
# 30                     NaN              NaN       NaN                     NaN
# 31  0m3Ze0cy8qBHSsV2exAfCw             94.0     False                  2009.0
# 32  0m3Ze0cy8qBHSsV2exAfCw             12.0     False                  2008.0
# 33                     NaN              NaN       NaN                     NaN
# 34                     NaN              NaN       NaN                     NaN
# 35                     NaN              NaN       NaN                     NaN
# 36                     NaN              NaN       NaN                     NaN
# 37                     NaN              NaN       NaN                     NaN
# 38                     NaN              NaN       NaN                     NaN
# 39                     NaN              NaN       NaN                     NaN
# 40                     NaN              NaN       NaN                     NaN
# 41                     NaN              NaN       NaN                     NaN
# 42  0tgVpDi06FyKpA1z0VMD4v           5617.0      True                  2018.0
# 43  0tgVpDi06FyKpA1z0VMD4v           1447.0      True                  2017.0
# 44                     NaN              NaN       NaN                     NaN
# 45                     NaN              NaN       NaN                     NaN
# 46                     NaN              NaN       NaN                     NaN
# 47  4kte3OcW800TPvOVgrLLj8            956.0      True                  2013.0
# 48  4kte3OcW800TPvOVgrLLj8           1579.0      True                  2012.0
# 49                     NaN              NaN       NaN                     NaN
# 50  3dmqIB2Qxe2XZobw9gXxJ6           1465.0      True                  1994.0
# 51  3dmqIB2Qxe2XZobw9gXxJ6             15.0     False                  1993.0
# 52                     NaN              NaN       NaN                     NaN
# 53                     NaN              NaN       NaN                     NaN
# 54                     NaN              NaN       NaN                     NaN
# 55                     NaN              NaN       NaN                     NaN

# %%
# Dropping unnecessary columns
merged_df.drop(['artist_id'], axis=1, inplace=True)
merged_df.drop(['album_id'], axis=1, inplace=True)
merged_df.drop(['track_count'], axis=1, inplace=True)
merged_df.drop(['song_id'], axis=1, inplace=True)

merged_df.head(100)
# Out:
#           spotify_track_id                                song_name  \
# 0   17lu4tymfnhmcIDlzBbtAb  For Those About To Rock (We Salute You)
# 1   2dbOYFfS7r7NAzquRvji9A                        Balls to the Wall
# 2   204523f9MSgEfc0oDJycNS                          Fast As a Shark
# 3   5O0FdpixX4OhV75VVUEt2p                        Restless and Wild
# 4   2CgXyaryyuxl35iMlvanD8                     Princess of the Dawn
# 5   7tPPgAFhBC0EQqyUmREjoU                    Put The Finger On You
# 6   3D3xCU3Q6oKbvnfzMNPJki                          Let's Get It Up
# 7   31KSQBbHS275MsHgHmTD21                         Inject The Venom
# 8   1is13OusVjtwAvLx5PcxcZ                               Snowballed
# 9   5ahPl557niKxia8Kquw1yh                               Evil Walks
# 10  0qHbOme0fFyIWLNie9HG2t                                   C.O.D.
# 11  7F6O76pKAZTrDywVmiWRGT                       Breaking The Rules
# 12  4NQJn1aSV9r6UmYErgzS4s                 Night Of The Long Knives
# 13  28rmYerSDjX81r5KCevY7G                               Spellbound
# 14  0y1QJc3SJVPKJ1OvFmFqe6                                  Go Down
# 15  6JLcvLZP4N8MRhvjG6SGaL                              Dog Eat Dog
# 16  753KutoAy00apPsplMRetG                        Let There Be Rock
# 17  0AIMPkZQbXGDVF6MrKqIj9                           Bad Boy Boogie
# 18  0Cq6A5FMPfaEl4W0VAU2WS                            Problem Child
# 19  17UNijHcIMuz5ik2UKeCjK                                 Overdose
# 20  79KUOd1p6yNjh2Jkr9IQHk             Hell Ain't A Bad Place To Be
# 21  4wYq5wugZDzQiMZQYG4wVB                        Whole Lotta Rosie
# 22  6FT9FZccFD6nE8dMNslz2n                            Walk On Water
# 23  1l6DV8qhmCdgOKLSAFzPOe                      Love In An Elevator
# 24  2KCJYwlBWxdlwyIYckIf6V                                 Rag Doll
# 25  6Qn5zhYkTa37e91HC1D7lb                            What It Takes
# 26  6Qn5zhYkTa37e91HC1D7lb                            What It Takes
# 27  6gQUbFwwdYXlKdmqRoWKJe                 Dude (Looks Like A Lady)
# 28  6gQUbFwwdYXlKdmqRoWKJe                 Dude (Looks Like A Lady)
# 29  1ZZZO1HhRYkCeY545WzBUw                        Janie's Got A Gun
# 30  4t1fWWJQs5V9YErfsrDslC                                   Cryin'
# 31  0m3Ze0cy8qBHSsV2exAfCw                                  Amazing
# 32  0m3Ze0cy8qBHSsV2exAfCw                                  Amazing
# 33  7kNNylJ1kswWbHeRM6UDuE                                Blind Man
# 34  4viUMIPk61pIvWUNDl0u4M                          Deuces Are Wild
# 35  7hVZJGsh5fxFtwaqgJq1nf                           The Other Side
# 36  4zfQER4owi8q6NL8Gg63Ya                                    Crazy
# 37  3O7LU72UPGoCzrOFU6LqGd                             Eat The Rich
# 38  4t46soaqA758rbukTO5pp1                                    Angel
# 39  6OZAcgTPxmjUTuiatU0Viq                       Livin' On The Edge
# 40  410rGaFDJPwjsr9m9RPCkz                        All I Really Want
# 41  3jS7bB0oXVOwGFZn3aE5NV                          You Oughta Know
# 42  0tgVpDi06FyKpA1z0VMD4v                                  Perfect
# 43  0tgVpDi06FyKpA1z0VMD4v                                  Perfect
# 44  2lE7oRoKssULAtbWViL385                        Hand In My Pocket
# 45  5YFIbauvzRGfW7xktVjR0I                        Right Through You
# 46  4ihV1wv7QmjbkLHaT9lA4s                                 Forgiven
# 47  4kte3OcW800TPvOVgrLLj8                                You Learn
# 48  4kte3OcW800TPvOVgrLLj8                                You Learn
# 49  735rjks7kQgWCjTQlIHMuH                           Head Over Feet
# 50  3dmqIB2Qxe2XZobw9gXxJ6                                Mary Jane
# 51  3dmqIB2Qxe2XZobw9gXxJ6                                Mary Jane
# 52  1d6KS9GH06JAd19uiBy9IE                                   Ironic
# 53  3i4NqznVYpSzS05D74avnj                           Not The Doctor
# 54  0nrRP2bk19rLc0orkWPQk2                                  Wake Up
# 55  6nuKQPmIZKOriUGXbMVcb9              You Oughta Know (Alternate)
#
#                         artist_name        date  track_number  duration_ms  \
# 0                             AC/DC  1981-11-23             1       344240
# 1                            Accept        1983             1       342600
# 2                            Accept        1982             1       228666
# 3                            Accept        1982             2       252093
# 4                            Accept        1982            10       375466
# 5                 Parachute Express  1998-09-30             3       167106
# 6                      Bella Thorne  2014-01-01            10       150360
# 7                             AC/DC  1981-11-23             4       210893
# 8                             AC/DC  1981-11-23             5       203133
# 9                             AC/DC  1981-11-23             6       263666
# 10                      $uicideboy$  2016-07-22             2       116114
# 11                            Atlus  2023-05-26            12       123637
# 12                            AC/DC  1981-11-23             9       205760
# 13        Siouxsie and the Banshees  2002-11-12            11       197533
# 14                            KALEO  2016-06-10             2       213706
# 15                     Tommy Lefroy  2022-07-27             1       169200
# 16                            AC/DC  1977-03-21             3       366346
# 17                      Mötley Crüe  1987-05-15             4       208293
# 18                      Dee Watkins  2021-11-17             1       105750
# 19                         honestav  2024-01-13             1       235885
# 20                            AC/DC  1977-03-21             7       254120
# 21                            AC/DC  1977-03-21             8       333800
# 22           Thirty Seconds To Mars  2018-04-06             1       185466
# 23                        Aerosmith  1994-01-01             2       321826
# 24                        Aerosmith  1987-01-01             3       265693
# 25                  Imagine Dragons  2017-06-23             3       201240
# 26                  Imagine Dragons  2017-06-23             3       201240
# 27                        Aerosmith  1987-01-01             5       265773
# 28                        Aerosmith  1987-01-01             5       265773
# 29                        Aerosmith  2011-01-01            11       328560
# 30                        Aerosmith  1993-01-01             9       308560
# 31                       Kanye West  2008-11-24             4       238333
# 32                       Kanye West  2008-11-24             4       238333
# 33        Manfred Mann's Earth Band        1976             1       428133
# 34                        Aerosmith  1994-01-01            10       215866
# 35                  Michael Marcagi  2023-12-11             1       164227
# 36                    Fuerza Regida  2023-10-20             6       204815
# 37                        Aerosmith  1993-01-01             2       250600
# 38                    Natanael Cano  2023-06-30             9       188666
# 39                        Aerosmith  1994-01-01            15       381400
# 40                       The Marías  2021-06-25             4       191800
# 41                Alanis Morissette        1995             2       249493
# 42                       Ed Sheeran  2017-03-03             5       263400
# 43                       Ed Sheeran  2017-03-03             5       263400
# 44                Alanis Morissette        1995             4       222013
# 45                Alanis Morissette        1995             5       176133
# 46                               ¥$  2024-02-09            13       368739
# 47                            Ne-Yo  2012-01-01             3       251626
# 48                            Ne-Yo  2012-01-01             3       251626
# 49                Alanis Morissette        1995             8       267293
# 50  Tom Petty and the Heartbreakers  2008-05-20            17       273600
# 51  Tom Petty and the Heartbreakers  2008-05-20            17       273600
# 52                Alanis Morissette        1995            10       230000
# 53                Alanis Morissette        1995            11       226266
# 54                           Avicii  2013-01-01             1       247426
# 55           Vitamin String Quartet  2000-10-24            13       248733
#
#                                            album_name  PopularityScore  \
# 0             For Those About to Rock (We Salute You)              NaN
# 1                                   Balls To The Wall              NaN
# 2                                   Restless And Wild              NaN
# 3                                   Restless And Wild              NaN
# 4                                   Restless And Wild              NaN
# 5                                      Feel the Music              NaN
# 6                         Disney Channel Play It Loud              NaN
# 7             For Those About to Rock (We Salute You)              NaN
# 8             For Those About to Rock (We Salute You)              NaN
# 9             For Those About to Rock (We Salute You)              NaN
# 10                                    Radical $uicide              NaN
# 11                                  High Expectations              NaN
# 12            For Those About to Rock (We Salute You)              NaN
# 13                                     The Best Of...              NaN
# 14                                                A/B            274.0
# 15                                        Dog Eat Dog              NaN
# 16                                  Let There Be Rock              NaN
# 17                                Girls, Girls, Girls              NaN
# 18                                    Problem Child 3              NaN
# 19                                I’d Rather Overdose              NaN
# 20                                  Let There Be Rock              NaN
# 21                                  Let There Be Rock              NaN
# 22                                            AMERICA              NaN
# 23                                           Big Ones              NaN
# 24                                 Permanent Vacation           1294.0
# 25                                             Evolve           2372.0
# 26                                             Evolve              9.0
# 27                                 Permanent Vacation            728.0
# 28                                 Permanent Vacation            895.0
# 29                    Tough Love: Best Of The Ballads              NaN
# 30                                         Get A Grip              NaN
# 31                                  808s & Heartbreak             94.0
# 32                                  808s & Heartbreak             12.0
# 33                                The Roaring Silence              NaN
# 34                                           Big Ones              NaN
# 35                                     The Other Side              NaN
# 36                          Pa las Baby's Y Belikeada              NaN
# 37                                         Get A Grip              NaN
# 38                                       Nata Montana              NaN
# 39                                           Big Ones              NaN
# 40                                             CINEMA              NaN
# 41                 Jagged Little Pill (2015 Remaster)              NaN
# 42                                         ÷ (Deluxe)           5617.0
# 43                                         ÷ (Deluxe)           1447.0
# 44                 Jagged Little Pill (2015 Remaster)              NaN
# 45                 Jagged Little Pill (2015 Remaster)              NaN
# 46                                         VULTURES 1              NaN
# 47                            R.E.D. (Deluxe Edition)            956.0
# 48                            R.E.D. (Deluxe Edition)           1579.0
# 49                 Jagged Little Pill (2015 Remaster)              NaN
# 50                                      Greatest Hits           1465.0
# 51                                      Greatest Hits             15.0
# 52                 Jagged Little Pill (2015 Remaster)              NaN
# 53                 Jagged Little Pill (2015 Remaster)              NaN
# 54                                               True              NaN
# 55  Strung Out On Jagged Little Pill: VSQ Performs...              NaN
#
#    IsPopular  MeasuredPopularityYear
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
# 5        NaN                     NaN
# 6        NaN                     NaN
# 7        NaN                     NaN
# 8        NaN                     NaN
# 9        NaN                     NaN
# 10       NaN                     NaN
# 11       NaN                     NaN
# 12       NaN                     NaN
# 13       NaN                     NaN
# 14     False                  2017.0
# 15       NaN                     NaN
# 16       NaN                     NaN
# 17       NaN                     NaN
# 18       NaN                     NaN
# 19       NaN                     NaN
# 20       NaN                     NaN
# 21       NaN                     NaN
# 22       NaN                     NaN
# 23       NaN                     NaN
# 24      True                  1988.0
# 25      True                  2018.0
# 26     False                  2017.0
# 27     False                  1988.0
# 28      True                  1987.0
# 29       NaN                     NaN
# 30       NaN                     NaN
# 31     False                  2009.0
# 32     False                  2008.0
# 33       NaN                     NaN
# 34       NaN                     NaN
# 35       NaN                     NaN
# 36       NaN                     NaN
# 37       NaN                     NaN
# 38       NaN                     NaN
# 39       NaN                     NaN
# 40       NaN                     NaN
# 41       NaN                     NaN
# 42      True                  2018.0
# 43      True                  2017.0
# 44       NaN                     NaN
# 45       NaN                     NaN
# 46       NaN                     NaN
# 47      True                  2013.0
# 48      True                  2012.0
# 49       NaN                     NaN
# 50      True                  1994.0
# 51     False                  1993.0
# 52       NaN                     NaN
# 53       NaN                     NaN
# 54       NaN                     NaN
# 55       NaN                     NaN

# %%
# Collecting extra track info from the chinook db track table
sql_track = "SELECT TrackId, Name FROM chinook.track;"
# Turning this into a dataframe
df_track = get_dataframe(user_id, pwd, host_name, src_dbname, sql_track)

df_track.head(5)
# Out:
#    TrackId                                     Name
# 0        1  For Those About To Rock (We Salute You)
# 1        2                        Balls to the Wall
# 2        3                          Fast As a Shark
# 3        4                        Restless and Wild
# 4        5                     Princess of the Dawn

# %%
# Merging the already merged track df with the track df from chinook db to get original TrackId
result_dim_tracks_df = pd.merge(df_track, merged_df, left_on='Name', right_on='song_name', how='inner')

# %%
result_dim_tracks_df.head(100)
# Out:
#     TrackId                                     Name        spotify_track_id  \
# 0         1  For Those About To Rock (We Salute You)  17lu4tymfnhmcIDlzBbtAb
# 1         2                        Balls to the Wall  2dbOYFfS7r7NAzquRvji9A
# 2         3                          Fast As a Shark  204523f9MSgEfc0oDJycNS
# 3         4                        Restless and Wild  5O0FdpixX4OhV75VVUEt2p
# 4         5                     Princess of the Dawn  2CgXyaryyuxl35iMlvanD8
# 5         6                    Put The Finger On You  7tPPgAFhBC0EQqyUmREjoU
# 6         7                          Let's Get It Up  3D3xCU3Q6oKbvnfzMNPJki
# 7         8                         Inject The Venom  31KSQBbHS275MsHgHmTD21
# 58              You Oughta Know (Alternate)           Vitamin String Quartet
#
#           date  track_number  duration_ms  \
# 0   1981-11-23             1       344240
# 1         1983             1       342600
# 2         1982             1       228666
# 3         1982             2       252093
# 4         1982            10       375466
# 5   1998-09-30             3       167106
# 6   2014-01-01            10       150360
# 7   1981-11-23             4       210893
# 8   1981-11-23             5       203133
# 9   1981-11-23             6       263666
# 10  2016-07-22             2       116114
# 11  2023-05-26            12       123637
# 12  1981-11-23             9       205760
# 13  2002-11-12            11       197533
# 14  2016-06-10             2       213706
# 15  2022-07-27             1       169200
# 16  1977-03-21             3       366346
# 17  1987-05-15             4       208293
# 18  2021-11-17             1       105750
# 19  2024-01-13             1       235885
# 20  1977-03-21             7       254120
# 21  1977-03-21             8       333800
# 22  2018-04-06             1       185466
# 23  1994-01-01             2       321826
# 24  1987-01-01             3       265693
# 25  2017-06-23             3       201240
# 26  2017-06-23             3       201240
# 27  1987-01-01             5       265773
# 28  1987-01-01             5       265773
# 29  2011-01-01            11       328560
# 30  1993-01-01             9       308560
# 31  2008-11-24             4       238333
# 32  2008-11-24             4       238333
# 33        1976             1       428133
# 34  1994-01-01            10       215866
# 35  2023-12-11             1       164227
# 36  2023-10-20             6       204815
# 37  1993-01-01             2       250600
# 38  2023-06-30             9       188666
# 39  2023-06-30             9       188666
# 40  1994-01-01            15       381400
# 41  2021-06-25             4       191800
# 42        1995             2       249493
# 43  2017-03-03             5       263400
# 44  2017-03-03             5       263400
# 45  2017-03-03             5       263400
# 46  2017-03-03             5       263400
# 47        1995             4       222013
# 48        1995             5       176133
# 49  2024-02-09            13       368739
# 50  2012-01-01             3       251626
# 51  2012-01-01             3       251626
# 52        1995             8       267293
# 53  2008-05-20            17       273600
# 54  2008-05-20            17       273600
# 55        1995            10       230000
# 56        1995            11       226266
# 57  2013-01-01             1       247426
# 58  2000-10-24            13       248733
#
#                                            album_name  PopularityScore  \
# 0             For Those About to Rock (We Salute You)              NaN
# 1                                   Balls To The Wall              NaN
# 2                                   Restless And Wild              NaN
# 3                                   Restless And Wild              NaN
# 4                                   Restless And Wild              NaN
# 5                                      Feel the Music              NaN
# 6                         Disney Channel Play It Loud              NaN
# 7             For Those About to Rock (We Salute You)              NaN
# 8             For Those About to Rock (We Salute You)              NaN
# 9             For Those About to Rock (We Salute You)              NaN
# 10                                    Radical $uicide              NaN
# 11                                  High Expectations              NaN
# 12            For Those About to Rock (We Salute You)              NaN
# 13                                     The Best Of...              NaN
# 14                                                A/B            274.0
# 15                                        Dog Eat Dog              NaN
# 16                                  Let There Be Rock              NaN
# 17                                Girls, Girls, Girls              NaN
# 18                                    Problem Child 3              NaN
# 19                                I’d Rather Overdose              NaN
# 20                                  Let There Be Rock              NaN
# 21                                  Let There Be Rock              NaN
# 22                                            AMERICA              NaN
# 23                                           Big Ones              NaN
# 24                                 Permanent Vacation           1294.0
# 25                                             Evolve           2372.0
# 26                                             Evolve              9.0
# 27                                 Permanent Vacation            728.0
# 28                                 Permanent Vacation            895.0
# 29                    Tough Love: Best Of The Ballads              NaN
# 30                                         Get A Grip              NaN
# 31                                  808s & Heartbreak             94.0
# 32                                  808s & Heartbreak             12.0
# 33                                The Roaring Silence              NaN
# 34                                           Big Ones              NaN
# 35                                     The Other Side              NaN
# 36                          Pa las Baby's Y Belikeada              NaN
# 37                                         Get A Grip              NaN
# 38                                       Nata Montana              NaN
# 39                                       Nata Montana              NaN
# 40                                           Big Ones              NaN
# 41                                             CINEMA              NaN
# 42                 Jagged Little Pill (2015 Remaster)              NaN
# 43                                         ÷ (Deluxe)           5617.0
# 44                                         ÷ (Deluxe)           1447.0
# 45                                         ÷ (Deluxe)           5617.0
# 46                                         ÷ (Deluxe)           1447.0
# 47                 Jagged Little Pill (2015 Remaster)              NaN
# 48                 Jagged Little Pill (2015 Remaster)              NaN
# 49                                         VULTURES 1              NaN
# 50                            R.E.D. (Deluxe Edition)            956.0
# 51                            R.E.D. (Deluxe Edition)           1579.0
# 52                 Jagged Little Pill (2015 Remaster)              NaN
# 53                                      Greatest Hits           1465.0
# 54                                      Greatest Hits             15.0
# 55                 Jagged Little Pill (2015 Remaster)              NaN
# 56                 Jagged Little Pill (2015 Remaster)              NaN
# 57                                               True              NaN
# 58  Strung Out On Jagged Little Pill: VSQ Performs...              NaN
#
#    IsPopular  MeasuredPopularityYear
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
# 5        NaN                     NaN
# 6        NaN                     NaN
# 7        NaN                     NaN
# 8        NaN                     NaN
# 9        NaN                     NaN
# 10       NaN                     NaN
# 11       NaN                     NaN
# 12       NaN                     NaN
# 13       NaN                     NaN
# 14     False                  2017.0
# 15       NaN                     NaN
# 16       NaN                     NaN
# 17       NaN                     NaN
# 18       NaN                     NaN
# 19       NaN                     NaN
# 20       NaN                     NaN
# 21       NaN                     NaN
# 22       NaN                     NaN
# 23       NaN                     NaN
# 24      True                  1988.0
# 25      True                  2018.0
# 26     False                  2017.0
# 27     False                  1988.0
# 28      True                  1987.0
# 29       NaN                     NaN
# 30       NaN                     NaN
# 31     False                  2009.0
# 32     False                  2008.0
# 33       NaN                     NaN
# 34       NaN                     NaN
# 35       NaN                     NaN
# 36       NaN                     NaN
# 37       NaN                     NaN
# 38       NaN                     NaN
# 39       NaN                     NaN
# 40       NaN                     NaN
# 41       NaN                     NaN
# 42       NaN                     NaN
# 43      True                  2018.0
# 44      True                  2017.0
# 45      True                  2018.0
# 46      True                  2017.0
# 47       NaN                     NaN
# 48       NaN                     NaN
# 49       NaN                     NaN
# 50      True                  2013.0
# 51      True                  2012.0
# 52       NaN                     NaN
# 53      True                  1994.0
# 54     False                  1993.0
# 55       NaN                     NaN
# 56       NaN                     NaN
# 57       NaN                     NaN
# 58       NaN                     NaN

# %%
# Dropping unnecessary cols
result_dim_tracks_df.drop(['song_name'], axis=1, inplace=True)
result_dim_tracks_df.drop(['spotify_track_id'], axis=1, inplace=True)
result_dim_tracks_df.head(100)
# Out:
#     TrackId                                     Name  \
# 0         1  For Those About To Rock (We Salute You)
# 1         2                        Balls to the Wall
# 2         3                          Fast As a Shark
# 3         4                        Restless and Wild
# 4         5                     Princess of the Dawn
# 5         6                    Put The Finger On You
# 6         7                          Let's Get It Up
# 7         8                         Inject The Venom
# 8         9                               Snowballed
# 9        10                               Evil Walks
# 10       11                                   C.O.D.
# 11       12                       Breaking The Rules
# 12       13                 Night Of The Long Knives
# 13       14                               Spellbound
# 14       15                                  Go Down
# 15       16                              Dog Eat Dog
# 16       17                        Let There Be Rock
# 17       18                           Bad Boy Boogie
# 18       19                            Problem Child
# 19       20                                 Overdose
# 20       21             Hell Ain't A Bad Place To Be
# 21       22                        Whole Lotta Rosie
# 22       23                            Walk On Water
# 23       24                      Love In An Elevator
# 24       25                                 Rag Doll
# 25       26                            What It Takes
# 26       26                            What It Takes
# 27       27                 Dude (Looks Like A Lady)
# 28       27                 Dude (Looks Like A Lady)
# 29       28                        Janie's Got A Gun
# 30       29                                   Cryin'
# 31       30                                  Amazing
# 32       30                                  Amazing
# 33       31                                Blind Man
# 34       32                          Deuces Are Wild
# 35       33                           The Other Side
# 36       34                                    Crazy
# 37       35                             Eat The Rich
# 38       36                                    Angel
# 39     2447                                    Angel
# 40       37                       Livin' On The Edge
# 41       38                        All I Really Want
# 42       39                          You Oughta Know
# 43       40                                  Perfect
# 44       40                                  Perfect
# 45     2501                                  Perfect
# 46     2501                                  Perfect
# 47       41                        Hand In My Pocket
# 48       42                        Right Through You
# 49       43                                 Forgiven
# 50       44                                You Learn
# 51       44                                You Learn
# 52       45                           Head Over Feet
# 53       46                                Mary Jane
# 54       46                                Mary Jane
# 55       47                                   Ironic
# 56       48                           Not The Doctor
# 57       49                                  Wake Up
# 58       50              You Oughta Know (Alternate)
#
#                         artist_name        date  track_number  duration_ms  \
# 0                             AC/DC  1981-11-23             1       344240
# 1                            Accept        1983             1       342600
# 2                            Accept        1982             1       228666
# 3                            Accept        1982             2       252093
# 4                            Accept        1982            10       375466
# 5                 Parachute Express  1998-09-30             3       167106
# 6                      Bella Thorne  2014-01-01            10       150360
# 7                             AC/DC  1981-11-23             4       210893
# 8                             AC/DC  1981-11-23             5       203133
# 9                             AC/DC  1981-11-23             6       263666
# 10                      $uicideboy$  2016-07-22             2       116114
# 11                            Atlus  2023-05-26            12       123637
# 12                            AC/DC  1981-11-23             9       205760
# 13        Siouxsie and the Banshees  2002-11-12            11       197533
# 14                            KALEO  2016-06-10             2       213706
# 15                     Tommy Lefroy  2022-07-27             1       169200
# 16                            AC/DC  1977-03-21             3       366346
# 17                      Mötley Crüe  1987-05-15             4       208293
# 18                      Dee Watkins  2021-11-17             1       105750
# 19                         honestav  2024-01-13             1       235885
# 20                            AC/DC  1977-03-21             7       254120
# 21                            AC/DC  1977-03-21             8       333800
# 22           Thirty Seconds To Mars  2018-04-06             1       185466
# 23                        Aerosmith  1994-01-01             2       321826
# 24                        Aerosmith  1987-01-01             3       265693
# 25                  Imagine Dragons  2017-06-23             3       201240
# 26                  Imagine Dragons  2017-06-23             3       201240
# 27                        Aerosmith  1987-01-01             5       265773
# 28                        Aerosmith  1987-01-01             5       265773
# 29                        Aerosmith  2011-01-01            11       328560
# 30                        Aerosmith  1993-01-01             9       308560
# 31                       Kanye West  2008-11-24             4       238333
# 32                       Kanye West  2008-11-24             4       238333
# 33        Manfred Mann's Earth Band        1976             1       428133
# 34                        Aerosmith  1994-01-01            10       215866
# 35                  Michael Marcagi  2023-12-11             1       164227
# 36                    Fuerza Regida  2023-10-20             6       204815
# 37                        Aerosmith  1993-01-01             2       250600
# 38                    Natanael Cano  2023-06-30             9       188666
# 39                    Natanael Cano  2023-06-30             9       188666
# 40                        Aerosmith  1994-01-01            15       381400
# 41                       The Marías  2021-06-25             4       191800
# 42                Alanis Morissette        1995             2       249493
# 43                       Ed Sheeran  2017-03-03             5       263400
# 44                       Ed Sheeran  2017-03-03             5       263400
# 45                       Ed Sheeran  2017-03-03             5       263400
# 46                       Ed Sheeran  2017-03-03             5       263400
# 47                Alanis Morissette        1995             4       222013
# 48                Alanis Morissette        1995             5       176133
# 49                               ¥$  2024-02-09            13       368739
# 50                            Ne-Yo  2012-01-01             3       251626
# 51                            Ne-Yo  2012-01-01             3       251626
# 52                Alanis Morissette        1995             8       267293
# 53  Tom Petty and the Heartbreakers  2008-05-20            17       273600
# 54  Tom Petty and the Heartbreakers  2008-05-20            17       273600
# 55                Alanis Morissette        1995            10       230000
# 56                Alanis Morissette        1995            11       226266
# 57                           Avicii  2013-01-01             1       247426
# 58           Vitamin String Quartet  2000-10-24            13       248733
#
#                                            album_name  PopularityScore  \
# 0             For Those About to Rock (We Salute You)              NaN
# 1                                   Balls To The Wall              NaN
# 2                                   Restless And Wild              NaN
# 3                                   Restless And Wild              NaN
# 4                                   Restless And Wild              NaN
# 5                                      Feel the Music              NaN
# 6                         Disney Channel Play It Loud              NaN
# 7             For Those About to Rock (We Salute You)              NaN
# 8             For Those About to Rock (We Salute You)              NaN
# 9             For Those About to Rock (We Salute You)              NaN
# 10                                    Radical $uicide              NaN
# 11                                  High Expectations              NaN
# 12            For Those About to Rock (We Salute You)              NaN
# 13                                     The Best Of...              NaN
# 14                                                A/B            274.0
# 15                                        Dog Eat Dog              NaN
# 16                                  Let There Be Rock              NaN
# 17                                Girls, Girls, Girls              NaN
# 18                                    Problem Child 3              NaN
# 19                                I’d Rather Overdose              NaN
# 20                                  Let There Be Rock              NaN
# 21                                  Let There Be Rock              NaN
# 22                                            AMERICA              NaN
# 23                                           Big Ones              NaN
# 24                                 Permanent Vacation           1294.0
# 25                                             Evolve           2372.0
# 26                                             Evolve              9.0
# 27                                 Permanent Vacation            728.0
# 28                                 Permanent Vacation            895.0
# 29                    Tough Love: Best Of The Ballads              NaN
# 30                                         Get A Grip              NaN
# 31                                  808s & Heartbreak             94.0
# 32                                  808s & Heartbreak             12.0
# 33                                The Roaring Silence              NaN
# 34                                           Big Ones              NaN
# 35                                     The Other Side              NaN
# 36                          Pa las Baby's Y Belikeada              NaN
# 37                                         Get A Grip              NaN
# 38                                       Nata Montana              NaN
# 39                                       Nata Montana              NaN
# 40                                           Big Ones              NaN
# 41                                             CINEMA              NaN
# 42                 Jagged Little Pill (2015 Remaster)              NaN
# 43                                         ÷ (Deluxe)           5617.0
# 44                                         ÷ (Deluxe)           1447.0
# 45                                         ÷ (Deluxe)           5617.0
# 46                                         ÷ (Deluxe)           1447.0
# 47                 Jagged Little Pill (2015 Remaster)              NaN
# 48                 Jagged Little Pill (2015 Remaster)              NaN
# 49                                         VULTURES 1              NaN
# 50                            R.E.D. (Deluxe Edition)            956.0
# 51                            R.E.D. (Deluxe Edition)           1579.0
# 52                 Jagged Little Pill (2015 Remaster)              NaN
# 53                                      Greatest Hits           1465.0
# 54                                      Greatest Hits             15.0
# 55                 Jagged Little Pill (2015 Remaster)              NaN
# 56                 Jagged Little Pill (2015 Remaster)              NaN
# 57                                               True              NaN
# 58  Strung Out On Jagged Little Pill: VSQ Performs...              NaN
#
#    IsPopular  MeasuredPopularityYear
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
# 5        NaN                     NaN
# 6        NaN                     NaN
# 7        NaN                     NaN
# 8        NaN                     NaN
# 9        NaN                     NaN
# 10       NaN                     NaN
# 11       NaN                     NaN
# 12       NaN                     NaN
# 13       NaN                     NaN
# 14     False                  2017.0
# 15       NaN                     NaN
# 16       NaN                     NaN
# 17       NaN                     NaN
# 18       NaN                     NaN
# 19       NaN                     NaN
# 20       NaN                     NaN
# 21       NaN                     NaN
# 22       NaN                     NaN
# 23       NaN                     NaN
# 24      True                  1988.0
# 25      True                  2018.0
# 26     False                  2017.0
# 27     False                  1988.0
# 28      True                  1987.0
# 29       NaN                     NaN
# 30       NaN                     NaN
# 31     False                  2009.0
# 32     False                  2008.0
# 33       NaN                     NaN
# 34       NaN                     NaN
# 35       NaN                     NaN
# 36       NaN                     NaN
# 37       NaN                     NaN
# 38       NaN                     NaN
# 39       NaN                     NaN
# 40       NaN                     NaN
# 41       NaN                     NaN
# 42       NaN                     NaN
# 43      True                  2018.0
# 44      True                  2017.0
# 45      True                  2018.0
# 46      True                  2017.0
# 47       NaN                     NaN
# 48       NaN                     NaN
# 49       NaN                     NaN
# 50      True                  2013.0
# 51      True                  2012.0
# 52       NaN                     NaN
# 53      True                  1994.0
# 54     False                  1993.0
# 55       NaN                     NaN
# 56       NaN                     NaN
# 57       NaN                     NaN
# 58       NaN                     NaN

# %%
# Renaming columns to better fit conventions of rest of tables
result_dim_tracks_df.rename(columns={'date': 'ReleaseDate'}, inplace=True)
result_dim_tracks_df.rename(columns={'track_number': 'AlbumTrackNumber'}, inplace=True)
result_dim_tracks_df.rename(columns={'album_name': 'AlbumName'}, inplace=True)
result_dim_tracks_df.rename(columns={'artist_name': 'Artist'}, inplace=True)
result_dim_tracks_df.rename(columns={'duration_ms': 'DurationMsec'}, inplace=True)

# %%
# Getting invoiceline table data from chinook into df
invoice_line_df = pd.read_sql("SELECT * FROM InvoiceLine", src_engine)
# Getting invoice table data from chinook into db
invoice_df = pd.read_sql("SELECT * FROM Invoice", src_engine)
# Getting track table data from chinook into db
track_df = pd.read_sql("SELECT * FROM Track", src_engine)
# Getting artist table data from chinook into db
artist_df = pd.read_sql("SELECT * FROM Artist", src_engine)

# %%
dim_artists_df = artist_df[['ArtistId', 'Name']].copy()
dim_artists_df.rename(columns={'Name': 'ArtistName'}, inplace=True)

# %%
dim_artists_df.head(100)
# Out:
#     ArtistId         ArtistName
# 0          1              AC/DC
# 1          2             Accept
# 2          3          Aerosmith
# 3          4  Alanis Morissette
# 4          5    Alice In Chains
# ..       ...                ...
# 95        96         Jota Quest
# 96        97       João Suplicy
# 97        98       Judas Priest
# 98        99      Legião Urbana
# 99       100      Lenny Kravitz
#
# [100 rows x 2 columns]

# %%
# Merging artists dimension table with one from chinook to get original ArtistId
dim_artists_merged_df = pd.merge(dim_tracks_df, dim_artists_df, left_on='artist_name', right_on='ArtistName', how='inner')
dim_artists_merged_df.head(50)
# Out:
#           spotify_track_id                                song_name  \
# 0   17lu4tymfnhmcIDlzBbtAb  For Those About To Rock (We Salute You)
# 1   31KSQBbHS275MsHgHmTD21                         Inject The Venom
# 2   1is13OusVjtwAvLx5PcxcZ                               Snowballed
# 3   5ahPl557niKxia8Kquw1yh                               Evil Walks
# 4   4NQJn1aSV9r6UmYErgzS4s                 Night Of The Long Knives
# 5   753KutoAy00apPsplMRetG                        Let There Be Rock
# 6   79KUOd1p6yNjh2Jkr9IQHk             Hell Ain't A Bad Place To Be
# 7   4wYq5wugZDzQiMZQYG4wVB                        Whole Lotta Rosie
# 8   2dbOYFfS7r7NAzquRvji9A                        Balls to the Wall
# 9   204523f9MSgEfc0oDJycNS                          Fast As a Shark
# 10  5O0FdpixX4OhV75VVUEt2p                        Restless and Wild
# 11  2CgXyaryyuxl35iMlvanD8                     Princess of the Dawn
# 12  0AIMPkZQbXGDVF6MrKqIj9                           Bad Boy Boogie
# 13  1l6DV8qhmCdgOKLSAFzPOe                      Love In An Elevator
# 14  2KCJYwlBWxdlwyIYckIf6V                                 Rag Doll
# 15  6gQUbFwwdYXlKdmqRoWKJe                 Dude (Looks Like A Lady)
# 16  1ZZZO1HhRYkCeY545WzBUw                        Janie's Got A Gun
# 17  4t1fWWJQs5V9YErfsrDslC                                   Cryin'
# 18  4viUMIPk61pIvWUNDl0u4M                          Deuces Are Wild
# 19  3O7LU72UPGoCzrOFU6LqGd                             Eat The Rich
# 20  6OZAcgTPxmjUTuiatU0Viq                       Livin' On The Edge
# 21  3jS7bB0oXVOwGFZn3aE5NV                          You Oughta Know
# 22  2lE7oRoKssULAtbWViL385                        Hand In My Pocket
# 23  5YFIbauvzRGfW7xktVjR0I                        Right Through You
# 24  735rjks7kQgWCjTQlIHMuH                           Head Over Feet
# 25  1d6KS9GH06JAd19uiBy9IE                                   Ironic
# 26  3i4NqznVYpSzS05D74avnj                           Not The Doctor
#
#                  artist_id        artist_name        date  track_number  \
# 0   711MCceyCBcFnzjGY4Q7Un              AC/DC  1981-11-23             1
# 1   711MCceyCBcFnzjGY4Q7Un              AC/DC  1981-11-23             4
# 2   711MCceyCBcFnzjGY4Q7Un              AC/DC  1981-11-23             5
# 3   711MCceyCBcFnzjGY4Q7Un              AC/DC  1981-11-23             6
# 4   711MCceyCBcFnzjGY4Q7Un              AC/DC  1981-11-23             9
# 5   711MCceyCBcFnzjGY4Q7Un              AC/DC  1977-03-21             3
# 6   711MCceyCBcFnzjGY4Q7Un              AC/DC  1977-03-21             7
# 7   711MCceyCBcFnzjGY4Q7Un              AC/DC  1977-03-21             8
# 8   3JDIAtVrJdQ7GFOX26LYpv             Accept        1983             1
# 9   3JDIAtVrJdQ7GFOX26LYpv             Accept        1982             1
# 10  3JDIAtVrJdQ7GFOX26LYpv             Accept        1982             2
# 11  3JDIAtVrJdQ7GFOX26LYpv             Accept        1982            10
# 12  0cc6vw3VN8YlIcvr1v7tBL        Mötley Crüe  1987-05-15             4
# 13  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1994-01-01             2
# 14  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1987-01-01             3
# 15  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1987-01-01             5
# 16  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  2011-01-01            11
# 17  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1993-01-01             9
# 18  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1994-01-01            10
# 19  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1993-01-01             2
# 20  7Ey4PD4MYsKc5I2dolUwbH          Aerosmith  1994-01-01            15
# 21  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995             2
# 22  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995             4
# 23  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995             5
# 24  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995             8
# 25  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995            10
# 26  6ogn9necmbUdCppmNnGOdi  Alanis Morissette        1995            11
#
#     duration_ms                album_id  \
# 0        344240  7DUvURQ0wfA1kgG8j99frR
# 1        210893  7DUvURQ0wfA1kgG8j99frR
# 2        203133  7DUvURQ0wfA1kgG8j99frR
# 3        263666  7DUvURQ0wfA1kgG8j99frR
# 4        205760  7DUvURQ0wfA1kgG8j99frR
# 5        366346  3JwFNl80WWeXPiKEjIFbqa
# 6        254120  3JwFNl80WWeXPiKEjIFbqa
# 7        333800  3JwFNl80WWeXPiKEjIFbqa
# 8        342600  2twCPCDGJjVD90GWUjA8vN
# 9        228666  0xym0raBJhG64y1Oc179TX
# 10       252093  0xym0raBJhG64y1Oc179TX
# 11       375466  0xym0raBJhG64y1Oc179TX
# 12       208293  0vPZhR1KpbRNBOQBsDScS8
# 13       321826  2uT123xlHuqvz14JR0KQSs
# 14       265693  3XYqOJI1YlX40kJTdzFEzp
# 15       265773  3XYqOJI1YlX40kJTdzFEzp
# 16       328560  33lrptYaoQiDsAcZPXKFna
# 17       308560  180jTzor4W2MQ9HW5h5Fh4
# 18       215866  2uT123xlHuqvz14JR0KQSs
# 19       250600  180jTzor4W2MQ9HW5h5Fh4
# 20       381400  2uT123xlHuqvz14JR0KQSs
# 21       249493  5Ap3F8CxjjsQKZGASDcHNA
# 22       222013  5Ap3F8CxjjsQKZGASDcHNA
# 23       176133  5Ap3F8CxjjsQKZGASDcHNA
# 24       267293  5Ap3F8CxjjsQKZGASDcHNA
# 25       230000  5Ap3F8CxjjsQKZGASDcHNA
# 26       226266  5Ap3F8CxjjsQKZGASDcHNA
#
#                                  album_name  track_count  ArtistId  \
# 0   For Those About to Rock (We Salute You)           10         1
# 1   For Those About to Rock (We Salute You)           10         1
# 2   For Those About to Rock (We Salute You)           10         1
# 3   For Those About to Rock (We Salute You)           10         1
# 4   For Those About to Rock (We Salute You)           10         1
# 5                         Let There Be Rock            8         1
# 6                         Let There Be Rock            8         1
# 7                         Let There Be Rock            8         1
# 8                         Balls To The Wall           12         2
# 9                         Restless And Wild           10         2
# 10                        Restless And Wild           10         2
# 11                        Restless And Wild           10         2
# 12                      Girls, Girls, Girls           15       109
# 13                                 Big Ones           15         3
# 14                       Permanent Vacation           12         3
# 15                       Permanent Vacation           12         3
# 16          Tough Love: Best Of The Ballads           12         3
# 17                               Get A Grip           14         3
# 18                                 Big Ones           15         3
# 19                               Get A Grip           14         3
# 20                                 Big Ones           15         3
# 21       Jagged Little Pill (2015 Remaster)           13         4
# 22       Jagged Little Pill (2015 Remaster)           13         4
# 23       Jagged Little Pill (2015 Remaster)           13         4
# 24       Jagged Little Pill (2015 Remaster)           13         4
# 25       Jagged Little Pill (2015 Remaster)           13         4
# 26       Jagged Little Pill (2015 Remaster)           13         4
#
#            ArtistName
# 0               AC/DC
# 1               AC/DC
# 2               AC/DC
# 3               AC/DC
# 4               AC/DC
# 5               AC/DC
# 6               AC/DC
# 7               AC/DC
# 8              Accept
# 9              Accept
# 10             Accept
# 11             Accept
# 12        Mötley Crüe
# 13          Aerosmith
# 14          Aerosmith
# 15          Aerosmith
# 16          Aerosmith
# 17          Aerosmith
# 18          Aerosmith
# 19          Aerosmith
# 20          Aerosmith
# 21  Alanis Morissette
# 22  Alanis Morissette
# 23  Alanis Morissette
# 24  Alanis Morissette
# 25  Alanis Morissette
# 26  Alanis Morissette

# %%
# Load the artist popularity data from csv file into a pandas df
artist_pop_df = pd.read_csv('artist_pop.csv', sep='\t')
# Rename cols to better fit conventions of other tables
artist_pop_df.rename(columns={'year': 'MeasuredPopularityYear', 'is_pop': 'IsPopular', 'year_end_score': 'PopularityScore'}, inplace=True)

artist_pop_df.head(3)
# Out:
#                 artist_id  PopularityScore  IsPopular  MeasuredPopularityYear
# 0  3TVXtAsR1Inumwj472S9r4           115282       True                    2018
# 1  0LyfQWJT6nXafLPZqxe9Of            78376       True                    2018
# 2  6eUKZXaKkcviH0Ku9w2n3V            60969       True                    2018

# %%
dim_artist_final_df = pd.merge(dim_artists_merged_df, artist_pop_df, on='artist_id', how='inner')

# %%
# Dropping unecessary cols
dim_artist_final_df.drop(['spotify_track_id'], axis=1, inplace=True)
dim_artist_final_df.drop(['song_name'], axis=1, inplace=True)
dim_artist_final_df.drop(['artist_id'], axis=1, inplace=True)
dim_artist_final_df.drop(['artist_name'], axis=1, inplace=True)
dim_artist_final_df.drop(['date'], axis=1, inplace=True)
dim_artist_final_df.drop(['track_number'], axis=1, inplace=True)
dim_artist_final_df.drop(['duration_ms'], axis=1, inplace=True)
dim_artist_final_df.drop(['album_id'], axis=1, inplace=True)
dim_artist_final_df.drop(['album_name'], axis=1, inplace=True)
dim_artist_final_df.drop(['track_count'], axis=1, inplace=True)

# Dropping duplicate rows
dim_artist_final_df = dim_artist_final_df.drop_duplicates()

dim_artist_final_df.head(100)
# Out:
#      ArtistId         ArtistName  PopularityScore  IsPopular  \
# 0           1              AC/DC            19627       True
# 1           1              AC/DC             9272       True
# 2           1              AC/DC            17461       True
# 3           1              AC/DC            22897       True
# 4           1              AC/DC            16351       True
# ..        ...                ...              ...        ...
# 336         3          Aerosmith             3691       True
# 337         3          Aerosmith              664       True
# 597         4  Alanis Morissette             1302       True
# 598         4  Alanis Morissette             1605       True
# 599         4  Alanis Morissette              318      False
#
#      MeasuredPopularityYear
# 0                      2018
# 1                      2017
# 2                      2016
# 3                      2015
# 4                      2014
# ..                      ...
# 336                    1974
# 337                    1973
# 597                    2016
# 598                    2015
# 599                    2014
#
# [100 rows x 5 columns]

# %%
# Merging invoiceline df with selected columns from invoice df
fact_sales_basic = pd.merge(invoice_line_df, invoice_df[['InvoiceId', 'CustomerId', 'InvoiceDate']], on='InvoiceId')
# Merging the previously combined df fact_sales_basic with selected columns from track_df
fact_sales_df = pd.merge(fact_sales_basic, track_df[['TrackId', 'Name']], on='TrackId', how='left')
# Rename columns for clarity and consistency
fact_sales_df.rename(columns={'InvoiceDate': 'SaleDate', 'Name': 'TrackName'}, inplace=True)

# %%
# Merging fact sales df with dim tracks df for some extra info
fact_sales_df = pd.merge(fact_sales_df, result_dim_tracks_df, on='TrackId', how='left')

# %%
fact_sales_df.head(10)
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0              1          1        2       0.99         1           2
# 1              2          1        4       0.99         1           2
# 2              3          2        6       0.99         1           4
# 3              4          2        8       0.99         1           4
# 4              5          2       10       0.99         1           4
# 5              6          2       12       0.99         1           4
# 6              7          3       16       0.99         1           8
# 7              8          3       20       0.99         1           8
# 8              9          3       24       0.99         1           8
# 9             10          3       28       0.99         1           8
#
#     SaleDate              TrackName                   Name             Artist  \
# 0 2021-01-01      Balls to the Wall      Balls to the Wall             Accept
# 1 2021-01-01      Restless and Wild      Restless and Wild             Accept
# 2 2021-01-02  Put The Finger On You  Put The Finger On You  Parachute Express
# 3 2021-01-02       Inject The Venom       Inject The Venom              AC/DC
# 4 2021-01-02             Evil Walks             Evil Walks              AC/DC
# 5 2021-01-02     Breaking The Rules     Breaking The Rules              Atlus
# 6 2021-01-03            Dog Eat Dog            Dog Eat Dog       Tommy Lefroy
# 7 2021-01-03               Overdose               Overdose           honestav
# 8 2021-01-03    Love In An Elevator    Love In An Elevator          Aerosmith
# 9 2021-01-03      Janie's Got A Gun      Janie's Got A Gun          Aerosmith
#
#   ReleaseDate  AlbumTrackNumber  DurationMsec  \
# 0        1983               1.0      342600.0
# 1        1982               2.0      252093.0
# 2  1998-09-30               3.0      167106.0
# 3  1981-11-23               4.0      210893.0
# 4  1981-11-23               6.0      263666.0
# 5  2023-05-26              12.0      123637.0
# 6  2022-07-27               1.0      169200.0
# 7  2024-01-13               1.0      235885.0
# 8  1994-01-01               2.0      321826.0
# 9  2011-01-01              11.0      328560.0
#
#                                  AlbumName  PopularityScore IsPopular  \
# 0                        Balls To The Wall              NaN       NaN
# 1                        Restless And Wild              NaN       NaN
# 2                           Feel the Music              NaN       NaN
# 3  For Those About to Rock (We Salute You)              NaN       NaN
# 4  For Those About to Rock (We Salute You)              NaN       NaN
# 5                        High Expectations              NaN       NaN
# 6                              Dog Eat Dog              NaN       NaN
# 7                      I’d Rather Overdose              NaN       NaN
# 8                                 Big Ones              NaN       NaN
# 9          Tough Love: Best Of The Ballads              NaN       NaN
#
#    MeasuredPopularityYear
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN

# %%
# Dropping unnecessary cols
fact_sales_df.drop(['Name'], axis=1, inplace=True)
fact_sales_df.drop(['MeasuredPopularityYear'], axis=1, inplace=True)
fact_sales_df.drop(['IsPopular'], axis=1, inplace=True)
fact_sales_df.drop(['PopularityScore'], axis=1, inplace=True)
fact_sales_df.drop(['AlbumTrackNumber'], axis=1, inplace=True)
fact_sales_df.drop(['DurationMsec'], axis=1, inplace=True)

# %%
fact_sales_df.head(100)
# Out:
#     InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0               1          1        2       0.99         1           2
# 1               2          1        4       0.99         1           2
# 2               3          2        6       0.99         1           4
# 3               4          2        8       0.99         1           4
# 4               5          2       10       0.99         1           4
# ..            ...        ...      ...        ...       ...         ...
# 95             96         18      548       0.99         1          31
# 96             97         18      554       0.99         1          31
# 97             98         19      563       0.99         1          40
# 98             99         19      572       0.99         1          40
# 99            100         19      581       0.99         1          40
#
#      SaleDate              TrackName             Artist ReleaseDate  \
# 0  2021-01-01      Balls to the Wall             Accept        1983
# 1  2021-01-01      Restless and Wild             Accept        1982
# 2  2021-01-02  Put The Finger On You  Parachute Express  1998-09-30
# 3  2021-01-02       Inject The Venom              AC/DC  1981-11-23
# 4  2021-01-02             Evil Walks              AC/DC  1981-11-23
# ..        ...                    ...                ...         ...
# 95 2021-03-09     Smoke On The Water                NaN         NaN
# 96 2021-03-09    Trampled Under Foot                NaN         NaN
# 97 2021-03-14          União Da Ilha                NaN         NaN
# 98 2021-03-14     Put Your Lights On                NaN         NaN
# 99 2021-03-14              Primavera                NaN         NaN
#
#                                   AlbumName
# 0                         Balls To The Wall
# 1                         Restless And Wild
# 2                            Feel the Music
# 3   For Those About to Rock (We Salute You)
# 4   For Those About to Rock (We Salute You)
# ..                                      ...
# 95                                      NaN
# 96                                      NaN
# 97                                      NaN
# 98                                      NaN
# 99                                      NaN
#
# [100 rows x 11 columns]

# %%
start_date = '2000-01-01'
end_date = '2024-12-31'

# Set date range for df
dates = pd.date_range(start=start_date, end=end_date)

# %%
# Create dim_date_df with a single column 'Date' containing date values
dim_date_df = pd.DataFrame({'Date': dates})

# Add a more columns to the DataFrame by extracting each from the 'Date' column
dim_date_df['Year'] = dim_date_df['Date'].dt.year
dim_date_df['Month'] = dim_date_df['Date'].dt.month
dim_date_df['Day'] = dim_date_df['Date'].dt.day
dim_date_df['WeekOfYear'] = dim_date_df['Date'].dt.isocalendar().week
dim_date_df['Quarter'] = dim_date_df['Date'].dt.quarter
dim_date_df['DayOfWeek'] = dim_date_df['Date'].dt.dayofweek
dim_date_df['DayName'] = dim_date_df['Date'].dt.day_name()
dim_date_df['IsWeekend'] = dim_date_df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
# Sending all dfs to music_data db as tables
fact_sales_df.to_sql(name='fact_sales', con=engine, if_exists='replace', index=False)
dim_artist_final_df.to_sql(name='dim_artist', con=engine, if_exists='replace', index=False)
dim_date_df.to_sql(name='dim_date', con=engine, if_exists='replace', index=False)
result_dim_tracks_df.to_sql(name='dim_tracks', con=engine, if_exists='replace', index=False)
# Out:
# 59
